# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[3,48,5,16,78,8]

# %%
y=[11,52,34,42,59,6]

# %%
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.scatter(x,y) #scattered graph

# %%
exp=[.3,0,.3,0,0,0]
plt.pie(y,labels=x,explode=exp,shadow=1,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x148210f8ef0>,
# ...
#  [Text(1.37996063158898, 0.23602681047826674, '3'),
#   Text(0.45975633030110546, 0.9993118215792611, '48'),
#   Text(-1.0907129014159063, 0.8776932076100941, '5'),
#   Text(-0.9691133437338364, -0.5204030428398966, '16'),
#   Text(0.5054176151565786, -0.9770122999683458, '78'),
#   Text(1.0953076069557586, -0.10149505478026917, '8')],
#  [Text(0.88711754887863, 0.1517315210217429, '5.4%'),
#   Text(0.2507761801642393, 0.5450791754068697, '25.5%'),
#   Text(-0.701172579481654, 0.5642313477493461, '16.7%'),
#   Text(-0.5286072784002743, -0.28385620518539806, '20.6%'),
#   Text(0.2756823355399519, -0.532915799982734, '28.9%'),
#   Text(0.5974405128849591, -0.05536093897105591, '2.9%')])
